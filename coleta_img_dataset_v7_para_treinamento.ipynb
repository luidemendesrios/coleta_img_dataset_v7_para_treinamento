# %% [markdown]
# <a href="https://colab.research.google.com/github/luidemendesrios/coleta_img_dataset_v7_para_treinamento/blob/main/coleta_img_dataset_v7_para_treinamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coleta e catalogação das imagens dos objetos para treinamento**

# %% [markdown]
# **Clonando o repositório da ferramenta**

# %%
# !git clone https://github.com/EscVM/OIDv4_Toolkit.git
# Out:
# Cloning into 'OIDv4_Toolkit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422 (from 1)
# Receiving objects: 100% (422/422), 34.08 MiB | 28.40 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %% [markdown]
# **Acessando diretório da ferramenta**

# %%
cd OIDv4_Toolkit/
# Out:
# /content/OIDv4_Toolkit

# %% [markdown]
# **Instalando todas as bibliotecas necessárias**

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 41.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 84.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.21.2
#     Uninstalling docutils-0.21.2:
#       Successfully uninstalled docutils-0.21.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sphinx 8.1.3 requires docutils<0.22,>=0.20, but you have docutils 0.16 which is incompatible.
# ...

# %%
# !pip show docutils
# Out:
# Name: docutils
# Version: 0.16
# Summary: Docutils -- Python Documentation Utilities
# Home-page: http://docutils.sourceforge.net/
# Author: David Goodger
# Author-email: goodger@python.org
# License: public domain, Python, 2-Clause BSD, GPL 3 (see COPYING.txt)
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: awscli, Sphinx

# %% [markdown]
# O **docutils** é usado principalmente para:
#
# **Gerar documentação:** Converter arquivos reST para outros formatos, como HTML, LaTeX, PDF e outros.
#
# **Processamento de texto:** Analisar e manipular texto em reST.
#
# **Criação de ferramentas de documentação:** Fornece uma base para a construção de sistemas de documentação mais complexos.

# %% [markdown]
# **Fazendo o download das imagens**

# %% [markdown]
# https://storage.googleapis.com/openimages/web/visualizer/index.html?type=detection&set=train&c=%2Fm%2F0663v

# %%
# !ls /content/ #comando do shell (Bash) que lista o conteúdo do diretório /content/.
#O ! no início indica que o comando deve ser executado no shell do sistema operacional do Colab, e não como um comando Python.
# Out:
# OIDv4_Toolkit  sample_data

# %%
# !python main.py downloader --classes Person Guitar Pizza --type_csv train --limit 500 --multiclasses 1
#Comand para baixar as classes Guitar e Pizza que serão usadas para treinar 500 item de cada classe e o último argumento salva tudo numa classe só.
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Person', 'Guitar', 'Pizza'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...145%, 0 MB, 37219 KB/s, 0 seconds passed
# ...

# %% [markdown]
# **Conjunto de imagens de validação**

# %%
# !python main.py downloader --classes Person Guitar Pizza --type_csv test --limit 100 --multiclasses 1
#Esse outro comando vai realizar o teste com 20 itens de cada classe
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Person', 'Guitar', 'Pizza'] together.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 49 MB, 37608 KB/s, 1 seconds passed
# ...

# %% [markdown]
# # **Convertendo os arquivos de anotação**

# %% [markdown]
# **Colocar as classes no arquivo classes.txt**

# %%
# !cat classes.txt #Comando para exibir o conteúdo do arquivo classes.txt na tela
# Out:
# Apple
# Orange
# Light switch

# %%
# !echo -e 'Person\nGuitar\nPizza' > classes.txt #Comando para salvar no arquivo classes.txt os nomes das classes um e cada linha

# %% [markdown]
# **Clonando o repositório da ferramenta**

# %%
# !git clone -n https://github.com/Hemilibeatriz/TreinamentoCustomizadoYolo.git
# Out:
# Cloning into 'TreinamentoCustomizadoYolo'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 34 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 1.13 MiB | 6.94 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
cd TreinamentoCustomizadoYolo/
# Out:
# /content/OIDv4_Toolkit/TreinamentoCustomizadoYolo

# %%
# !git checkout HEAD converter_anotacoes.py #É um comando de shell que interage com um repositório Git local.
#Ele tem como objetivo verificar a versão mais recente do arquivo converter_anotacoes.py que está no branch atual
# Out:
# Updated 1 path from 2c25c08

# %%
# !mv converter_anotacoes.py /content/OIDv4_Toolkit/ #Mover o arquivo converter_anotacoes.py para o diretório /content/OIDv4_Toolkit/.

# %%
ls

# %%
cd ..
# Out:
# /content/OIDv4_Toolkit

# %% [markdown]
# **Executando o arquivo de conversão**

# %%
# !python converter_anotacoes.py
# Out:
# Subdiretorio atual: train
# Convertendo os annotations para a classe:  Person_Guitar_Pizza
# 100% 1485/1485 [00:44<00:00, 33.31it/s]
# Subdiretorio atual: test
# Convertendo os annotations para a classe:  Person_Guitar_Pizza
# 100% 300/300 [00:03<00:00, 75.17it/s]

# %% [markdown]
# # **Compactar o Dataset para salvar no Google Driver**

# %% [markdown]
# **Obs:** Entrar no diretório OIDv4_Toolkit pasta OID - Dataset - e renomear a pasta test de nome Person_Guitar_Pizza para valid e a do train para obj
#
# ![Captura de tela 2025-01-07 092453.png](data:image/png;base64,...)

# %%
cd OID/Dataset/train/
# Out:
# /content/OIDv4_Toolkit/OID/Dataset/train

# %%
# !zip -r ../../../obj.zip obj -x obj/Label/*
# Out:
#   adding: obj/ (stored 0%)
#   adding: obj/5ad89401232bee0a.txt (deflated 31%)
#   adding: obj/b46a575355b65ea8.txt (deflated 12%)
#   adding: obj/1682b07d3e094b9e.jpg (deflated 0%)
#   adding: obj/15ac6b22cd6ee832.txt (deflated 12%)
#   adding: obj/3161f1bbffd18ff7.jpg (deflated 1%)
#   adding: obj/5754469ae0b8cb41.jpg (deflated 0%)
#   adding: obj/978a420d46ad9db8.txt (deflated 45%)
#   adding: obj/7040fe702d51633b.txt (deflated 63%)
#   adding: obj/e8797ff7c7d45e97.jpg (deflated 0%)
#   adding: obj/2d1c21972fee3040.jpg (deflated 0%)
#   adding: obj/73ed8fb1221774a2.jpg (deflated 0%)
#   adding: obj/d879b067d64fba11.txt (deflated 44%)
#   adding: obj/b88e80064ae9bbbd.jpg (deflated 0%)
#   adding: obj/028a393270285c2a.jpg (deflated 0%)
#   adding: obj/34a37472e53e200c.jpg (deflated 0%)
#   adding: obj/be557386e0be5efb.txt (deflated 30%)
#   adding: obj/27d8de0e4d2579dd.txt (deflated 55%)
#   adding: obj/12a35bcd716372ff.jpg (deflated 0%)
# ...

# %%
ls
# Out:
# obj/

# %%
cd ..
# Out:
# /content/OIDv4_Toolkit/OID/Dataset

# %%
cd test/
# Out:
# /content/OIDv4_Toolkit/OID/Dataset/test

# %%
ls
# Out:
# valid/

# %%
# !zip -r ../../../valid.zip valid -x valid/Label/*
# Out:
#   adding: valid/ (stored 0%)
#   adding: valid/098055c5133befa9.txt (deflated 13%)
#   adding: valid/4d936caf5c622b08.jpg (deflated 0%)
#   adding: valid/fdff2445de6949c4.txt (deflated 60%)
#   adding: valid/67840c2c16b7fe3f.txt (deflated 25%)
#   adding: valid/c1c43a3c541fc5f5.txt (deflated 26%)
#   adding: valid/68e2e0ed173941f4.txt (deflated 21%)
#   adding: valid/25da71eb8e08685b.txt (deflated 36%)
#   adding: valid/96f048158389a7be.txt (deflated 20%)
#   adding: valid/9ef178b401668cc0.txt (deflated 44%)
#   adding: valid/d58a34a665ee32fc.jpg (deflated 0%)
#   adding: valid/1a2a2ac059b13bf9.jpg (deflated 0%)
#   adding: valid/a4e339b0823004cb.jpg (deflated 0%)
#   adding: valid/1d2d3266e4fb10fd.jpg (deflated 0%)
#   adding: valid/56bd6455730e0615.jpg (deflated 0%)
#   adding: valid/fc68de7c80f01fbb.txt (deflated 27%)
#   adding: valid/178b09d58a514255.jpg (deflated 0%)
#   adding: valid/cc35cbd92d3105e4.txt (deflated 47%)
#   adding: valid/6a8885bbdfdbc5f7.jpg (deflated 0%)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True) #Baixar o drive para o ambiente do colab para ter acesso a pasta TreinamentoCustomuzadoYOLO
# Out:
# Mounted at /content/gdrive

# %%
ls
# Out:
# valid/

# %%
cd ../../../
# Out:
# /content/OIDv4_Toolkit

# %%
# !cp ./obj.zip /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO
#Cópia o arquivo obj.zip que está no diretório atual (./) para o diretório /content/gdrive/My Drive/TreinamentoCustomizadoYOLO.
# Out:
# cp: cannot stat './obj.zip': No such file or directory

# %%
# !cp ./valid.zip /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO

# %% [markdown]
# # **Edição dos arquivos de configuração**

# %%
pwd
# Out:
# '/content/OIDv4_Toolkit'

# %%
cd ..
# Out:
# /content

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15873, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 15873 (delta 12), reused 7 (delta 7), pack-reused 15850 (from 3)
# Receiving objects: 100% (15873/15873), 14.50 MiB | 17.01 MiB/s, done.
# Resolving deltas: 100% (10679/10679), done.

# %%
cd darknet/
# Out:
# /content/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ...

# %% [markdown]
# # **Arquivos a serem editados**

# %%
pwd
# Out:
# '/content/darknet'

# %% [markdown]
# **Modificações no .cfg**

# %%
# !cp cfg/yolov4.cfg /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO/yolov4_custom.cfg

# %% [markdown]
# Obs: Ir no Google Drive e alterar o arquivo yolov4_custom.cfg
#
# ![Captura de tela 2025-01-07 093834.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-01-07 094113.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-01-07 094341.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-01-07 094439.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela 2025-01-07 094520.png](data:image/png;base64,...)

# %% [markdown]
# # **Modificações no obj.names e obj.data**

# %%
# !touch obj.names
# !touch obj.data

# %%
# !cp obj.names /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO/obj.names
# !cp obj.data /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO/obj.data

# %% [markdown]
# **Obs:** Ir para o Google Drive na pasta TreinamentoCustomizadoYOLO e escrever nos arquivos obj.names e obj.data

# %% [markdown]
# **Na obj.names**

# %% [markdown]
# ![Captura de tela 2025-01-07 095206.png](data:image/png;base64,...)

# %% [markdown]
# **Na obj.data**

# %% [markdown]
# ![Captura de tela 2025-01-07 095610.png](data:image/png;base64,...)

# %% [markdown]
# # **Gerando o arquivo train.txt e test.txt**

# %%
cd ..
# Out:
# /content

# %%
cd OIDv4_Toolkit/
# Out:
# /content/OIDv4_Toolkit

# %%
# !unzip obj.zip -d ./data
# Out:
# Archive:  obj.zip
#    creating: ./data/obj/
#   inflating: ./data/obj/5ad89401232bee0a.txt
#   inflating: ./data/obj/b46a575355b65ea8.txt
#   inflating: ./data/obj/1682b07d3e094b9e.jpg
#   inflating: ./data/obj/15ac6b22cd6ee832.txt
#   inflating: ./data/obj/3161f1bbffd18ff7.jpg
#   inflating: ./data/obj/5754469ae0b8cb41.jpg
#   inflating: ./data/obj/978a420d46ad9db8.txt
#   inflating: ./data/obj/7040fe702d51633b.txt
#   inflating: ./data/obj/e8797ff7c7d45e97.jpg
#   inflating: ./data/obj/2d1c21972fee3040.jpg
#   inflating: ./data/obj/73ed8fb1221774a2.jpg
#   inflating: ./data/obj/d879b067d64fba11.txt
#   inflating: ./data/obj/b88e80064ae9bbbd.jpg
#   inflating: ./data/obj/028a393270285c2a.jpg
#   inflating: ./data/obj/34a37472e53e200c.jpg
#   inflating: ./data/obj/be557386e0be5efb.txt
#   inflating: ./data/obj/27d8de0e4d2579dd.txt
#   inflating: ./data/obj/12a35bcd716372ff.jpg
#   inflating: ./data/obj/0282e739a90410c2.jpg
#   inflating: ./data/obj/7bcd31dfb456ac28.txt
# ...

# %%
# !unzip valid.zip -d ./data
# Out:
# Archive:  valid.zip
#    creating: ./data/valid/
#   inflating: ./data/valid/098055c5133befa9.txt
#   inflating: ./data/valid/4d936caf5c622b08.jpg
#   inflating: ./data/valid/fdff2445de6949c4.txt
#   inflating: ./data/valid/67840c2c16b7fe3f.txt
#   inflating: ./data/valid/c1c43a3c541fc5f5.txt
#   inflating: ./data/valid/68e2e0ed173941f4.txt
#   inflating: ./data/valid/25da71eb8e08685b.txt
#   inflating: ./data/valid/96f048158389a7be.txt
#   inflating: ./data/valid/9ef178b401668cc0.txt
#   inflating: ./data/valid/d58a34a665ee32fc.jpg
#   inflating: ./data/valid/1a2a2ac059b13bf9.jpg
#   inflating: ./data/valid/a4e339b0823004cb.jpg
#   inflating: ./data/valid/1d2d3266e4fb10fd.jpg
#   inflating: ./data/valid/56bd6455730e0615.jpg
#   inflating: ./data/valid/fc68de7c80f01fbb.txt
#   inflating: ./data/valid/178b09d58a514255.jpg
#   inflating: ./data/valid/cc35cbd92d3105e4.txt
#   inflating: ./data/valid/6a8885bbdfdbc5f7.jpg
#   inflating: ./data/valid/d58a34a665ee32fc.txt
# ...

# %%
ls
# Out:
# classes.txt             images/  modules/  README.md                    valid.zip
# converter_anotacoes.py  LICENSE  obj.zip   requirements.txt
# data/                   main.py  OID/      TreinamentoCustomizadoYolo/

# %%
cd TreinamentoCustomizadoYolo/
# Out:
# /content/OIDv4_Toolkit/TreinamentoCustomizadoYolo

# %%
# !git checkout HEAD gera_train.py
# Out:
# Updated 1 path from 2c25c08

# %%
# !git checkout HEAD gera_test.py
# Out:
# Updated 1 path from 2c25c08

# %%
# !mv gera_train.py /content/OIDv4_Toolkit/

# %%
# !mv gera_test.py /content/OIDv4_Toolkit/

# %%
pwd
# Out:
# '/content/OIDv4_Toolkit/TreinamentoCustomizadoYolo'

# %%
cd ..
# Out:
# /content/OIDv4_Toolkit

# %%
# !python /content/OIDv4_Toolkit/gera_train.py

# %%
# !python /content/OIDv4_Toolkit/gera_test.py

# %%
cd data
# Out:
# /content/OIDv4_Toolkit/data

# %%
# !cp train.txt /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO/train.txt

# %%
# !cp test.txt /content/gdrive/My\ Drive/TreinamentoCustomizadoYOLO/test.txt
